# %% [markdown]
# **Installation of Faker library**

# %%
pip install Faker
# Out:
# Requirement already satisfied: Faker in /usr/local/lib/python3.7/dist-packages (13.3.2)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from Faker) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->Faker) (1.15.0)

# %%
from faker import Faker
fakeobject = Faker()

# %% [markdown]
# **Generating basic data points (Name, Address, Job, Dates, etc.)**

# %%
fakeobject.name()
# Out:
# 'Bethany Esparza'

# %%
print(fakeobject.first_name())
print(fakeobject.last_name())
# Out:
# Sarah
# Graham

# %%
fakeobject.address()
# Out:
# '15764 Kara Track\nDanielsside, TX 98234'

# %%
print(fakeobject.job())
# Out:
# Financial controller

# %%
print(fakeobject.city())
# Out:
# Port Patrick

# %%
print(fakeobject.text())
# Out:
# Majority stop professional small course attack role choice. Option candidate prevent lay take decide activity condition. Happen place easy federal.

# %%
#This statement generates a dummy word
print(f'single word: {fakeobject.word()}')
#This statement genetaes a list of 5 dummy words
print(f'list of 5 words: {fakeobject.words(5)}')
# Out:
# single word: machine
# list of 5 words: ['color', 'station', 'through', 'individual', 'yard']

# %%
listofwords = ['laptop', 'technology', 'science', 'mathematics', 'space']
print(f'random unique words: {fakeobject.words(3, listofwords, True)}')
# Out:
# random unique words: ['laptop', 'mathematics', 'space']

# %%
print(f'Random int: {fakeobject.random_int()}')
print(f'Random int: {fakeobject.random_int(0, 10)}')
print(f'Random digit: {fakeobject.random_digit()}')
# Out:
# Random int: 1203
# Random int: 6
# Random digit: 8

# %%
print("Faker methods related to Date and Time")
print(f'Date of birth: {fakeobject.date_of_birth()}')
print(f'Year: {fakeobject.year()}')
print(f'Month: {fakeobject.month()}')
print(f'Month name: {fakeobject.month_name()}')
print(f'Day of week: {fakeobject.day_of_week()}')
print(f'Day of month: {fakeobject.day_of_month()}')
print(f'Time zone: {fakeobject.timezone()}')
# Out:
# Faker methods related to Date and Time
# Date of birth: 1917-02-15
# Year: 1970
# Month: 05
# Month name: April
# Day of week: Sunday
# Day of month: 08
# Time zone: Pacific/Tongatapu

# %% [markdown]
# **Generating dummy profiles**

# %%
profile1 = fakeobject.simple_profile()
profile2 = fakeobject.simple_profile('M')
profile3 = fakeobject.profile(sex='F')
print(profile1)
print(profile2)
print(profile3)
# Out:
# {'username': 'zochoa', 'name': 'Audrey Russell', 'sex': 'F', 'address': 'PSC 7797, Box 6482\nAPO AA 22335', 'mail': 'thomasarmstrong@yahoo.com', 'birthdate': datetime.date(1947, 4, 26)}
# {'username': 'crystal74', 'name': 'Mr. Jerome Wolf', 'sex': 'M', 'address': '9280 Brian Manor\nFredborough, GA 61706', 'mail': 'brad30@gmail.com', 'birthdate': datetime.date(1925, 7, 2)}
# {'job': 'Recruitment consultant', 'company': 'Wise-Johnson', 'ssn': '647-88-5840', 'residence': '0231 Waters Hill\nLukechester, UT 43612', 'current_location': (Decimal('70.3550665'), Decimal('-21.801755')), 'blood_group': 'O+', 'website': ['http://sharp.info/'], 'username': 'keith09', 'name': 'Brooke Lee', 'sex': 'F', 'address': '227 Long Loaf\nPort Susan, OK 10654', 'mail': 'dmeyers@hotmail.com', 'birthdate': datetime.date(2020, 5, 3)}

# %% [markdown]
# **Generating unique data points**

# %%
names = [fakeobject.unique.name() for i in range(10)]
for i in range (0,len(names)):
  print(names[i])
# Out:
# Katherine Levine
# Mary Gamble
# Danielle Holland
# Jared Warner
# Jay Perez
# David Warner
# Karen Joseph
# Rhonda Pham
# Nancy Daniel
# Rebecca Lopez

# %%
Faker.seed(10)
print(fakeobject.name())
# Out:
# Jessica Lane

# %%
print(fakeobject.name())
# Out:
# Robert Colon

# %%
Faker.seed(10)
print(fakeobject.name())
# Out:
# Jessica Lane

# %% [markdown]
# **Generating currency-related information**

# %%
print(f'currency: {fakeobject.currency()}')
print(f'currency name: {fakeobject.currency_name()}')
print(f'currency code: {fakeobject.currency_code()}')
# Out:
# currency: ('GNF', 'Guinean franc')
# currency name: Serbian dinar
# currency code: SEK

# %%
print(f'currency name: {fakeobject.cryptocurrency_name()}')
print(f'currency code: {fakeobject.cryptocurrency()}')
# Out:
# currency name: PotCoin
# currency code: ('TRX', 'TRON')

# %% [markdown]
# **Generating Hashes and UUIDs**

# %%
print(f'sha256: {fakeobject.sha256()}')
print(f'md5: {fakeobject.md5()}')
print(f'uuid4: {fakeobject.uuid4()}')
# Out:
# sha256: 19e8d8d8a5398ee248d8cf784880e41d4f7faf0228fb109ca7b84206d302e479
# md5: d83fcdbfcd681f99a61d36162c861179
# uuid4: 3fffc830-137a-4777-93e8-eb437d763fb9

# %% [markdown]
# **Generating Internet-related data**

# %%
print("Domain related information")
print(f'Host name: {fakeobject.hostname()}')
print(f'Domain name: {fakeobject.domain_name()}')
print(f'Domain word: {fakeobject.domain_word()}')
print(f'TLD: {fakeobject.tld()}')
print("")
print("Email related information")
print(f'Email: {fakeobject.email()}')
print(f'Safe email: {fakeobject.safe_email()}')
print(f'Free email: {fakeobject.free_email()}')
print(f'Company email: {fakeobject.company_email()}')
print("")
print("Internet protocol related information")
print(f'IPv4: {fakeobject.ipv4()}')
print(f'IPv6: {fakeobject.ipv6()}')
print(f'MAC address: {fakeobject.mac_address()}')
# Out:
# Domain related information
# Host name: email-50.dalton-morrison.biz
# Domain name: campbell-leonard.info
# Domain word: jennings
# TLD: com
#
# Email related information
# Email: stephendalton@example.org
# Safe email: caustin@example.net
# Free email: youngjames@yahoo.com
# Company email: kelsey35@dunn.org
#
# Internet protocol related information
# IPv4: 42.2.196.127
# IPv6: 69b1:dcbf:f843:bdb8:396b:a83b:d798:c9cf
# MAC address: 7a:12:10:fe:9a:24

# %% [markdown]
# **Generating JSON data**

# %%
#Import libraries
from faker import Faker
import json
from random import randint
#Initilaiize the object
fakeobject = Faker()
#Method to generate dummy details of the employees
def input_data(x):
    employee_data ={}
    for i in range(0, x):
      employee_data[i]={}
      employee_data[i]['Employee Id']= randint(1, 10)
      employee_data[i]['name']= fakeobject.name()
      employee_data[i]['address']= fakeobject.address()
      employee_data[i]['job']= fakeobject.job()
      employee_data[i]['city']= fakeobject.city()
      print(employee_data)
    #dictionary dumped as json in a json file
    with open('employee.json', 'w') as fp:
      json.dump(employee_data, fp)
#defining the main method
def main():
    #variable to assign the number of employees
    number_of_employees = 2
    input_data(number_of_employees)
#Invoking the main method
main()
# Out:
# {0: {'Employee Id': 1, 'name': 'Sarah Hernandez', 'address': '211 Jackson Valley Apt. 566\nSanchezview, RI 68901', 'job': 'Editor, magazine features', 'city': 'West Stephenburgh'}}
# {0: {'Employee Id': 1, 'name': 'Sarah Hernandez', 'address': '211 Jackson Valley Apt. 566\nSanchezview, RI 68901', 'job': 'Editor, magazine features', 'city': 'West Stephenburgh'}, 1: {'Employee Id': 4, 'name': 'Terri Thompson', 'address': '6308 Martin Island Apt. 147\nAguilarfurt, NM 88758', 'job': 'Financial controller', 'city': 'Abigailfort'}}

# %% [markdown]
# **Generating data points in multiple languages**

# %%
from faker import Faker
fakeobject = Faker('ja_JP')
for i in range(1,6):
    print(i," ",fakeobject.name())
# Out:
# 1   高橋 稔
# 2   青木 くみ子
# 3   井上 春香
# 4   佐々木 さゆり
# 5   鈴木 舞

# %% [markdown]
# **Generating large datasets**

# %%
from faker import Faker
import pandas as pd
fakeobject = Faker()
person_data = [fakeobject.profile() for i in range(5)]
dataframe = pd.DataFrame(person_data)
dataframe
# Out:
#                                         job                        company  \
# 0                       Animal technologist                   Gonzales Inc
# 1  Geographical information systems officer        Diaz, Burton and Burton
# 2             Scientist, research (medical)  Gallagher, Blevins and Murphy
# 3                  Horticultural consultant           Banks, Snow and Reed
# 4              Administrator, Civil Service                    Ramirez PLC
#
#            ssn                                          residence  \
# 0  052-45-1520   2768 Cooper Green Suite 658\nLake John, AZ 90550
# 1  215-55-9991    316 Madison Keys Suite 576\nLake Kara, UT 39036
# 2  049-85-9475  5922 Catherine Way Suite 208\nChristophermouth...
# 3  535-80-7786  26318 Garcia Locks Apt. 451\nNew Michelle, AK ...
# 4  316-19-1713  950 Reid Terrace Suite 820\nNew Bruceborough, ...
#
#             current_location blood_group  \
# 0  (-37.4998485, 164.993365)          O-
# 1    (45.9644265, 88.108581)         AB+
# 2   (-50.9402325, 58.770133)          O-
# 3   (17.429113, -163.213662)          A+
# 4   (-50.639028, -15.825235)          O+
#
#                                              website           username  \
# 0                          [http://york-wright.com/]       zavalajustin
# 1  [https://barber-olson.info/, https://norris.co...      robinsonjulie
# 2  [https://www.holloway-short.com/, https://davi...           stacey06
# 3  [https://www.williams.com/, http://www.roberts...  claudiavalenzuela
# 4   [http://caldwell.info/, http://www.powell.info/]             kgarza
#
#                 name sex                                            address  \
# 0         Susan Wang   F      9635 Christopher Fields\nClarkville, ME 61286
# 1  Elizabeth Hawkins   F                          USNS Hudson\nFPO AA 78283
# 2        Kristy Huff   F  53722 Lamb Mountain Suite 022\nHernandezfurt, ...
# 3       Andrea Bates   F            697 Rogers Bypass\nBurtonfort, VT 48287
# 4      Maureen Moore   F  78598 Hernandez Row Suite 520\nBrownmouth, NC ...
#
#                        mail   birthdate
# 0         vwest@hotmail.com  1934-08-07
# 1   longmatthew@hotmail.com  1932-03-10
# 2  danielgriffith@yahoo.com  2004-08-28
# 3       taylorjon@gmail.com  1968-12-05
# 4         ybishop@gmail.com  2001-03-15
